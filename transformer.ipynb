# %%
# !nvidia-smi
# Out:
# Wed Apr 15 06:26:15 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# from google.colab import auth
# auth.authenticate_user()
# from oauth2client.client import GoogleCredentials
# creds = GoogleCredentials.get_application_default()
# import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
# vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144568 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.19-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.19-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.19-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# !ls /content/drive#/My Drive/transformer_task1/transformer_task
# Out:
# ls: cannot access '/content/drive#/My': No such file or directory
# ls: cannot access 'Drive/transformer_task1/transformer_task': No such file or directory

# %%
import sys
# sys.path.append('/content/drive/transformer_task1/transformer_task')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# from utils.data_loader import build_dataset,load_dataset

from utils.data_loader import build_dataset,load_dataset,preprocess_sentence,load_test_dataset

from utils.wv_loader import load_embedding_matrix,load_vocab
from utils.config import *
from gensim.models.word2vec import LineSentence, Word2Vec
import tensorflow as tf
import time
# Out:
# unable to import 'smart_open.gcs', disabling that module
# Building prefix dict from the default dictionary ...
# 2020-04-15 15:47:25,686 : DEBUG : Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# 2020-04-15 15:47:25,688 : DEBUG : Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.904 seconds.
# 2020-04-15 15:47:26,591 : DEBUG : Loading model cost 0.904 seconds.
# Prefix dict has been built successfully.
# 2020-04-15 15:47:26,592 : DEBUG : Prefix dict has been built successfully.

# %%
#数据处理
# build_dataset(train_data_path,test_data_path)

# %%
#数据处理
# build_dataset(train_data_path,test_data_path)

# %%
vocab,reverse_vocab=load_vocab(file_path=vocab_path)

# %%
len(vocab)
# Out:
# 31820

# %%
vocab
# Out:
# {'，': 0,
#  '|': 1,
#  '技师说': 2,
#  '车主说': 3,
#  '。': 4,
#  '？': 5,
#  '问题': 6,
#  '不': 7,
#  '没有': 8,
#  '好': 9,
#  '都': 10,
#  '需要': 11,
#  '一下': 12,
#  '！': 13,
#  '语音': 14,
#  '检查': 15,
#  '发动机': 16,
#  '换': 17,
#  '更换': 18,
#  '会': 19,
#  '图片': 20,
#  '车': 21,
#  '正常': 22,
#  '情况': 23,
#  '没': 24,
#  '故障': 25,
#  '机油': 26,
#  '说': 27,
#  '去': 28,
#  '谢谢': 29,
#  '看': 30,
#  '电脑': 31,
#  '这种': 32,
#  '现在': 33,
#  '建议': 34,
#  '不会': 35,
#  '传感器': 36,
#  '可能': 37,
#  '声音': 38,
#  '变速箱': 39,
#  '应该': 40,
#  '后': 41,
#  '清洗': 42,
#  '下': 43,
#  '有没有': 44,
#  '出现': 45,
#  '检查一下': 46,
#  '上': 47,
#  '是否': 48,
#  '是不是': 49,
#  '节气门': 50,
#  '启动': 51,
#  '影响': 52,
#  '?': 53,
#  '故障码': 54,
#  '不是': 55,
#  '大': 56,
#  '车子': 57,
#  '还': 58,
#  '看看': 59,
#  '跑': 60,
#  '公里': 61,
#  '左右': 62,
#  '很': 63,
#  '油': 64,
#  '做': 65,
#  '车辆': 66,
#  '火花塞': 67,
#  '师傅': 68,
#  '请问': 69,
#  '再': 70,
#  '位置': 71,
#  '开': 72,
#  '原因': 73,
#  '时': 74,
#  '年': 75,
#  '维修': 76,
#  '保养': 77,
#  '比较': 78,
#  '感觉': 79,
#  '行驶': 80,
#  '知道': 81,
#  '线路': 82,
#  '才': 83,
#  '里面': 84,
#  '导致': 85,
#  '先': 86,
#  '轮胎': 87,
#  '款': 88,
#  '4s店': 89,
#  '不好': 90,
#  '开关': 91,
#  '压力': 92,
#  '怠速': 93,
#  '拆': 94,
#  '坏': 95,
#  '电瓶': 96,
#  '刹车': 97,
#  '空调': 98,
#  '修理厂': 99,
#  '使用': 100,
#  '不能': 101,
#  '点火': 102,
#  '新': 103,
#  '大师': 104,
#  '造成': 105,
#  '汽油': 106,
#  '抖动': 107,
#  '钥匙': 108,
#  '系统': 109,
#  '地方': 110,
#  '检测': 111,
#  '钱': 112,
#  '灯': 113,
#  '进行': 114,
#  '两个': 115,
#  '显示': 116,
#  '不行': 117,
#  '万公里': 118,
#  '熄火': 119,
#  '加': 120,
#  '以后': 121,
#  '高': 122,
#  '大概': 123,
#  '插头': 124,
#  '不客气': 125,
#  '直接': 126,
#  '出来': 127,
#  '上面': 128,
#  '工作': 129,
#  '解决': 130,
#  '买': 131,
#  '档': 132,
#  '控制': 133,
#  '匹配': 134,
#  '这是': 135,
#  '找': 136,
#  '打开': 137,
#  '线': 138,
#  '喷油嘴': 139,
#  '缸': 140,
#  '2': 141,
#  '一点': 142,
#  '现象': 143,
#  '1': 144,
#  '想': 145,
#  '试试': 146,
#  '关系': 147,
#  '处理': 148,
#  '汽车': 149,
#  '.': 150,
#  '加油': 151,
#  '肯定': 152,
#  '水温': 153,
#  '起来': 154,
#  '离合器': 155,
#  '主要': 156,
#  '之前': 157,
#  '转': 158,
#  '踩': 159,
#  '一次': 160,
#  '不用': 161,
#  '异响': 162,
#  '有点': 163,
#  '挂': 164,
#  '皮带': 165,
#  '方向盘': 166,
#  '仪表': 167,
#  '具体': 168,
#  '螺丝': 169,
#  '损坏': 170,
#  '气门': 171,
#  '响': 172,
#  '时间': 173,
#  '自动': 174,
#  '之后': 175,
#  '怎么回事': 176,
#  '3': 177,
#  '不了': 178,
#  '问': 179,
#  '、': 180,
#  '东西': 181,
#  '油耗': 182,
#  '亮': 183,
#  '没事': 184,
#  '最好': 185,
#  '模块': 186,
#  '价格': 187,
#  '积碳': 188,
#  '原厂': 189,
#  '4': 190,
#  '只能': 191,
#  '4S店': 192,
#  '转速': 193,
#  '油门': 194,
#  '安装': 195,
#  '200': 196,
#  '重新': 197,
#  '确定': 198,
#  '方向': 199,
#  '空气': 200,
#  '数据': 201,
#  '今天': 202,
#  '点': 203,
#  '防冻液': 204,
#  '0': 205,
#  '小': 206,
#  '描述': 207,
#  '进气': 208,
#  '信号': 209,
#  '咨询': 210,
#  '高速': 211,
#  '保险': 212,
#  '已经': 213,
#  '拆下来': 214,
#  '水箱': 215,
#  '发现': 216,
#  '后面': 217,
#  '线圈': 218,
#  '底盘': 219,
#  '动力': 220,
#  '以前': 221,
#  '修': 222,
#  '中': 223,
#  '下面': 224,
#  '新车': 225,
#  '5': 226,
#  '出': 227,
#  '门': 228,
#  '店': 229,
#  '解答': 230,
#  '冷车': 231,
#  '前': 232,
#  '凸轮轴': 233,
#  '测量': 234,
#  '刹车片': 235,
#  '定位': 236,
#  '不要': 237,
#  '磨损': 238,
#  '油泵': 239,
#  '温度': 240,
#  '泵': 241,
#  '电机': 242,
#  '滤芯': 243,
#  '轴承': 244,
#  '继电器': 245,
#  '明显': 246,
#  '保险丝': 247,
#  '外面': 248,
#  '电磁阀': 249,
#  '这款': 250,
#  '正': 251,
#  '意思': 252,
#  '明天': 253,
#  '三元催化': 254,
#  '曲轴': 255,
#  '读取': 256,
#  '氧': 257,
#  '不到': 258,
#  '100': 259,
#  '助力': 260,
#  '风扇': 261,
#  '燃油': 262,
#  '正时': 263,
#  '电压': 264,
#  '内部': 265,
#  '容易': 266,
#  '大灯': 267,
#  '车身': 268,
#  '严重': 269,
#  '质量': 270,
#  '漏气': 271,
#  '10': 272,
#  '走': 273,
#  '关注': 274,
#  '好像': 275,
#  '导航': 276,
#  '4s': 277,
#  '烧': 278,
#  '间隙': 279,
#  '配件': 280,
#  '漏油': 281,
#  '引起': 282,
#  '里': 283,
#  '电': 284,
#  '加速': 285,
#  '转向': 286,
#  '玻璃': 287,
#  '哒': 288,
#  '反应': 289,
#  '麻烦': 290,
#  '车门': 291,
#  '离合': 292,
#  '特别': 293,
#  '才能': 294,
#  '月': 295,
#  '低': 296,
#  '电子': 297,
#  '太': 298,
#  '内': 299,
#  '听': 300,
#  '热车': 301,
#  '马达': 302,
#  '分析': 303,
#  '完': 304,
#  '原车': 305,
#  '合成': 306,
#  '6': 307,
#  '一定': 308,
#  '办法': 309,
#  '起步': 310,
#  '手动': 311,
#  '挡': 312,
#  '费用': 313,
#  '修复': 314,
#  '帮': 315,
#  '请': 316,
#  '本身': 317,
#  '发电机': 318,
#  '总成': 319,
#  '号': 320,
#  '装': 321,
#  '很多': 322,
#  '有时候': 323,
#  '车型': 324,
#  '必要': 325,
#  '随时': 326,
#  '前面': 327,
#  '查': 328,
#  '车主': 329,
#  '发出': 330,
#  '调': 331,
#  '重点': 332,
#  '四轮': 333,
#  '存在': 334,
#  '加装': 335,
#  '说明': 336,
#  '喷漆': 337,
#  '突然': 338,
#  '报': 339,
#  '变速器': 340,
#  '12': 341,
#  '刚': 342,
#  '防盗': 343,
#  '希望': 344,
#  '链条': 345,
#  '排气管': 346,
#  '看到': 347,
#  '属于': 348,
#  '数据流': 349,
#  '无法': 350,
#  '调整': 351,
#  '最近': 352,
#  '专用': 353,
#  '压': 354,
#  '必须': 355,
#  '功能': 356,
#  '档位': 357,
#  '回答': 358,
#  '连接': 359,
#  '灯亮': 360,
#  '型号': 361,
#  '减震器': 362,
#  '变形': 363,
#  '下来': 364,
#  '压缩机': 365,
#  '考虑': 366,
#  '元': 367,
#  '温器': 368,
#  '客气': 369,
#  '全': 370,
#  '一会': 371,
#  '响声': 372,
#  '调节': 373,
#  '弄': 374,
#  '方面': 375,
#  '几天': 376,
#  '效果': 377,
#  '放': 378,
#  '有时': 379,
#  '刹车油': 380,
#  '驾驶': 381,
#  '抖': 382,
#  '节': 383,
#  '关闭': 384,
#  '人': 385,
#  '判断': 386,
#  '报警': 387,
#  '左': 388,
#  '速度': 389,
#  '注意': 390,
#  '联系': 391,
#  '提示': 392,
#  '堵塞': 393,
#  '倒车': 394,
#  '放心': 395,
#  '仪表盘': 396,
#  '几个': 397,
#  '只': 398,
#  '排气': 399,
#  '升': 400,
#  '估计': 401,
#  '火': 402,
#  '电脑板': 403,
#  '垫': 404,
#  '减震': 405,
#  '打火': 406,
#  '诊断': 407,
#  '代码': 408,
#  '版': 409,
#  '修车': 410,
#  '前轮': 411,
#  '掉': 412,
#  '用车': 413,
#  '打不着': 414,
#  '方向机': 415,
#  '早上': 416,
#  '最': 417,
#  '固定': 418,
#  '40': 419,
#  '方法': 420,
#  '开车': 421,
#  '质保': 422,
#  '点击': 423,
#  '就行了': 424,
#  '换挡': 425,
#  '行': 426,
#  '打着': 427,
#  'T': 428,
#  '停车': 429,
#  '15': 430,
#  '觉得': 431,
#  '目前': 432,
#  '30': 433,
#  '不亮': 434,
#  '很大': 435,
#  '踩油门': 436,
#  '网上': 437,
#  '锁': 438,
#  '大众': 439,
#  '懂': 440,
#  '噪音': 441,
#  '到底': 442,
#  '品牌': 443,
#  '发动': 444,
#  '洗': 445,
#  '机': 446,
#  '涡轮': 447,
#  '暖风': 448,
#  '那种': 449,
#  '大修': 450,
#  '灯泡': 451,
#  '头像': 452,
#  '购买': 453,
#  '单独': 454,
#  '找到': 455,
#  '试一下': 456,
#  '排除': 457,
#  '不足': 458,
#  '高兴': 459,
#  '倒': 460,
#  '长': 461,
#  '测试': 462,
#  '毛病': 463,
#  '复位': 464,
#  '明白': 465,
#  '快': 466,
#  '解码器': 467,
#  '选择': 468,
#  '胎压': 469,
#  '轻微': 470,
#  '有个': 471,
#  '一起': 472,
#  '1.6': 473,
#  '水': 474,
#  '带': 475,
#  '设置': 476,
#  '状态': 477,
#  '进去': 478,
#  '清楚': 479,
#  '建议您': 480,
#  '踏板': 481,
#  '循环': 482,
#  '13': 483,
#  '行车': 484,
#  '差不多': 485,
#  '相关': 486,
#  '自动挡': 487,
#  '以上': 488,
#  '2.0': 489,
#  '手刹': 490,
#  '顿挫': 491,
#  '原来': 492,
#  '全部': 493,
#  '干净': 494,
#  '进': 495,
#  '高压': 496,
#  '专业': 497,
#  '免费': 498,
#  '胶套': 499,
#  '昨天': 500,
#  '积炭': 501,
#  '不好意思': 502,
#  '8': 503,
#  '改装': 504,
#  '11': 505,
#  '异常': 506,
#  '中间': 507,
#  '贵': 508,
#  '插': 509,
#  '帮助': 510,
#  '拆开': 511,
#  '7': 512,
#  '发': 513,
#  '右': 514,
#  '基本': 515,
#  '油路': 516,
#  '器': 517,
#  '气囊': 518,
#  '操作': 519,
#  '可能性': 520,
#  '松动': 521,
#  'ABS': 522,
#  '感谢': 523,
#  '度': 524,
#  '漏': 525,
#  '愉快': 526,
#  '接': 527,
#  '拔': 528,
#  '电源': 529,
#  '清除': 530,
#  '厉害': 531,
#  '老化': 532,
#  '电池': 533,
#  '一年': 534,
#  '支持': 535,
#  '车速': 536,
#  '码': 537,
#  '万': 538,
#  '油压': 539,
#  '燃烧': 540,
#  '老师': 541,
#  '修理店': 542,
#  '更': 543,
#  '照片': 544,
#  '修理': 545,
#  '试': 546,
#  '4S': 547,
#  '一根': 548,
#  '动': 549,
#  '朋友': 550,
#  '水泵': 551,
#  '每次': 552,
#  '缸盖': 553,
#  '少': 554,
#  '喇叭': 555,
#  '偏': 556,
#  '小时': 557,
#  '四个': 558,
#  '能够': 559,
#  '搭': 560,
#  '后轮': 561,
#  '一段时间': 562,
#  '刚才': 563,
#  '20': 564,
#  '就要': 565,
#  '动平衡': 566,
#  '部位': 567,
#  '厂家': 568,
#  '后备箱': 569,
#  '宝马': 570,
#  '完全': 571,
#  '轮毂': 572,
#  '观察': 573,
#  '多久': 574,
#  '升级': 575,
#  '这车': 576,
#  '低速': 577,
#  '偶尔': 578,
#  '停': 579,
#  '继续': 580,
#  '当时': 581,
#  '14': 582,
#  '过程': 583,
#  '油封': 584,
#  '三个': 585,
#  '球头': 586,
#  '部件': 587,
#  '拍': 588,
#  '遥控器': 589,
#  '刮': 590,
#  '油箱': 591,
#  '不同': 592,
#  '量': 593,
#  '线束': 594,
#  '半轴': 595,
#  '喷': 596,
#  '盖': 597,
#  '数': 598,
#  '听到': 599,
#  '换个': 600,
#  '图': 601,
#  '轮': 602,
#  '技师': 603,
#  '主': 604,
#  '气缸': 605,
#  '事故': 606,
#  '不够': 607,
#  '断': 608,
#  '改': 609,
#  '之间': 610,
#  '没什么': 611,
#  '担心': 612,
#  '喷油': 613,
#  '进入': 614,
#  '刚刚': 615,
#  '经常': 616,
#  '保险杠': 617,
#  '拆掉': 618,
#  '刹车盘': 619,
#  '超过': 620,
#  '测': 621,
#  '清理': 622,
#  '16': 623,
#  '遥控': 624,
#  '推荐': 625,
#  '变化': 626,
#  '无': 627,
#  '拉': 628,
#  '产生': 629,
#  '后来': 630,
#  '及时': 631,
#  '学习': 632,
#  '断电': 633,
#  '1.8': 634,
#  '确认': 635,
#  '要求': 636,
#  '颜色': 637,
#  '试车': 638,
#  '排量': 639,
#  '非常': 640,
#  '电路': 641,
#  '不错': 642,
#  '车上': 643,
#  '不响': 644,
#  '座椅': 645,
#  '解决问题': 646,
#  '牌子': 647,
#  '1.5': 648,
#  '怀疑': 649,
#  '副': 650,
#  '遇到': 651,
#  '上次': 652,
#  '读': 653,
#  '拉杆': 654,
#  '大约': 655,
#  '手动挡': 656,
#  '提速': 657,
#  '右边': 658,
#  '添加': 659,
#  '求': 660,
#  '平时': 661,
#  '半': 662,
#  '声': 663,
#  '拔掉': 664,
#  '3000': 665,
#  '分泵': 666,
#  '嘉实多': 667,
#  '碳': 668,
#  '热': 669,
#  '几次': 670,
#  '短路': 671,
#  '松': 672,
#  '17': 673,
#  '别克': 674,
#  '排': 675,
#  '包括': 676,
#  '增压': 677,
#  '钣金': 678,
#  '确实': 679,
#  '急': 680,
#  '片': 681,
#  '95': 682,
#  '天窗': 683,
#  '帮到': 684,
#  '就行': 685,
#  '修好': 686,
#  '是因为': 687,
#  '作用': 688,
#  '稳定': 689,
#  '09': 690,
#  '电阻': 691,
#  '安全': 692,
#  'D': 693,
#  '转动': 694,
#  '店里': 695,
#  '失火': 696,
#  '四': 697,
#  '美孚': 698,
#  '最后': 699,
#  '水管': 700,
#  '路': 701,
#  '堵': 702,
#  '单元': 703,
#  '中控': 704,
#  '怕': 705,
#  '祝您': 706,
#  '机滤': 707,
#  '悬挂': 708,
#  '刚换': 709,
#  '事': 710,
#  '按键': 711,
#  '供电': 712,
#  '程序': 713,
#  '稍微': 714,
#  '负极': 715,
#  '高温': 716,
#  '还要': 717,
#  '左边': 718,
#  '气阀': 719,
#  '检修': 720,
#  '所有': 721,
#  '发生': 722,
#  '齿轮': 723,
#  '冬天': 724,
#  '废': 725,
#  '性能': 726,
#  '没用': 727,
#  '谢谢您': 728,
#  '没换': 729,
#  '搞': 730,
#  '上去': 731,
#  '过来': 732,
#  '漆': 733,
#  '进气道': 734,
#  '电话': 735,
#  '5000': 736,
#  '增加': 737,
#  '300': 738,
#  '模式': 739,
#  '便宜': 740,
#  '记号': 741,
#  '按钮': 742,
#  '丰田': 743,
#  '鼓风机': 744,
#  '回': 745,
#  '开着': 746,
#  '润滑': 747,
#  '来说': 748,
#  '里程': 749,
#  '拆卸': 750,
#  '告诉': 751,
#  '慢慢': 752,
#  '挂挡': 753,
#  'abs': 754,
#  '当地': 755,
#  '管子': 756,
#  '下降': 757,
#  't': 758,
#  '不用谢': 759,
#  '80': 760,
#  '进气管': 761,
#  '脏': 762,
#  '接触': 763,
#  '漏水': 764,
#  '合适': 765,
#  '回复': 766,
#  '消失': 767,
#  '卖': 768,
#  '方便': 769,
#  '分钟': 770,
#  '后期': 771,
#  '混合气': 772,
#  '两根': 773,
#  '没电': 774,
#  '副驾驶': 775,
#  '密封': 776,
#  '撞': 777,
#  '整个': 778,
#  '达到': 779,
#  '起动': 780,
#  '工具': 781,
#  '原地': 782,
#  '要换': 783,
#  '图文': 784,
#  '阀': 785,
#  '冷': 786,
#  '支架': 787,
#  '机械': 788,
#  '打滑': 789,
#  '顶': 790,
#  '慢': 791,
#  '起动机': 792,
#  '进水': 793,
#  '摩擦': 794,
#  '冷却液': 795,
#  '阀体': 796,
#  '老': 797,
#  '一键': 798,
#  '回来': 799,
#  '盒': 800,
#  '雷达': 801,
#  '卡': 802,
#  '简单': 803,
#  '无力': 804,
#  '挺': 805,
#  '恩': 806,
#  '雨': 807,
#  '60': 808,
#  '缺缸': 809,
#  '到位': 810,
#  '感': 811,
#  '专用工具': 812,
#  '奔驰': 813,
#  '晚上': 814,
#  '找个': 815,
#  '震动': 816,
#  '天气': 817,
#  '92': 818,
#  '粘度': 819,
#  '空挡': 820,
#  '一对一': 821,
#  '弹簧': 822,
#  '请教': 823,
#  '1.4': 824,
#  '手机': 825,
#  '盖子': 826,
#  '油底壳': 827,
#  '一体': 828,
#  's': 829,
#  '总泵': 830,
#  '分离': 831,
#  '板': 832,
#  '吹': 833,
#  '臂': 834,
#  '跳': 835,
#  '升降': 836,
#  '二手车': 837,
#  '500': 838,
#  '室盖': 839,
#  '9': 840,
#  '一种': 841,
#  '有电': 842,
#  '黑色': 843,
#  '接触不良': 844,
#  '护板': 845,
#  '运转': 846,
#  '两': 847,
#  '问问': 848,
#  '燃烧室': 849,
#  '保险盒': 850,
#  '更好': 851,
#  '打不开': 852,
#  '范围': 853,
#  '我车': 854,
#  '一缸': 855,
#  '共振': 856,
#  '对车': 857,
#  '普通': 858,
#  '个人': 859,
#  '塑料': 860,
#  '拆装': 861,
#  '提供': 862,
#  '一块': 863,
#  '管路': 864,
#  '充电': 865,
#  '首保': 866,
#  '轴': 867,
#  '空滤': 868,
#  '差': 869,
#  '过大': 870,
#  'P': 871,
#  '漏电': 872,
#  '保修': 873,
#  '路面': 874,
#  '轮子': 875,
#  '机器': 876,
#  '旁边': 877,
#  '拉线': 878,
#  '视频': 879,
#  '基本上': 880,
#  '标准': 881,
#  '箱': 882,
#  '设备': 883,
#  '清洗剂': 884,
#  'L': 885,
#  '50': 886,
#  '附近': 887,
#  '准确': 888,
#  '没关系': 889,
#  '即可': 890,
#  '08': 891,
#  '亲': 892,
#  '马上': 893,
#  '800': 894,
#  '灯不亮': 895,
#  '换油': 896,
#  '真的': 897,
#  '指示灯': 898,
#  '本田': 899,
#  '样子': 900,
#  '两年': 901,
#  '技术': 902,
#  '重': 903,
#  '油管': 904,
#  '块钱': 905,
#  '生锈': 906,
#  '120': 907,
#  '奥迪': 908,
#  '好点': 909,
#  '原装': 910,
#  '真空': 911,
#  '部分': 912,
#  '三': 913,
#  '通电': 914,
#  '提问': 915,
#  '彻底': 916,
#  '消除': 917,
#  '下次': 918,
#  '松开': 919,
#  '一档': 920,
#  '区别': 921,
#  '1500': 922,
#  '做个': 923,
#  '编程': 924,
#  '块': 925,
#  '实际': 926,
#  '两次': 927,
#  '液压': 928,
#  '平衡杆': 929,
#  '关键': 930,
#  '不良': 931,
#  '机构': 932,
#  '老款': 933,
#  '驾驶室': 934,
#  '件': 935,
#  '现代': 936,
#  '越': 937,
#  '别人': 938,
#  '一点点': 939,
#  '当然': 940,
#  '滤清器': 941,
#  '大神': 942,
#  '索赔': 943,
#  '感应': 944,
#  '一声': 945,
#  '碳罐': 946,
#  '蓄电池': 947,
#  '换掉': 948,
#  '不稳': 949,
#  '软件': 950,
#  '两天': 951,
#  '路上': 952,
#  '400': 953,
#  '孔': 954,
#  '帮忙': 955,
#  '科鲁兹': 956,
#  '打铁': 957,
#  '第一次': 958,
#  '开启': 959,
#  '左侧': 960,
#  '电路图': 961,
#  '厂': 962,
#  '发动机舱': 963,
#  '多公里': 964,
#  '已': 965,
#  '每个': 966,
#  '右侧': 967,
#  '半年': 968,
#  '散热': 969,
#  '灯光': 970,
#  '速腾': 971,
#  '天': 972,
#  '变': 973,
#  '类似': 974,
#  '流量计': 975,
#  '指点': 976,
#  '台': 977,
#  '灯亮了': 978,
#  '柴油': 979,
#  '门锁': 980,
#  '凉车': 981,
#  '伏': 982,
#  '主机': 983,
#  '缺少': 984,
#  '刷': 985,
#  '万用表': 986,
#  '关': 987,
#  '三件套': 988,
#  '闪': 989,
#  '平衡': 990,
#  '标志': 991,
#  '后视镜': 992,
#  '好好': 993,
#  '信息': 994,
#  '降低': 995,
#  '活塞': 996,
#  '气': 997,
#  '够不够': 998,
#  '波箱': 999,
#  ...}

# %%
print(vocab['<START>'])
print(vocab["<STOP>"])
print(vocab["<PAD>"])
print(vocab["<UNK>"])
# Out:
# 31816
# 31817
# 31818
# 31819

# %%
#加载数据集
train_X,train_Y,test_X = load_dataset()

# %%
train_X.shape
# Out:
# (82873, 200)

# %%
train_X[0]
# Out:
# array([31816,   415,   903,     0,   260,   241,     0,   415,    10,
#           17,     2,    14,     1,     3,   103,    10,    17,     1,
#            3,   260,   241,     0,   415,     1,     2,    14,     1,
#            3,    17,   415,   475,     1,     3,    20,     1,     2,
#           14,     1,     3,   260,   903,     0,   576,   134,     1,
#            2,     7,    11,     1,     2,    18,   587,     6,     1,
#            3,    60,   466,  1654,   203,     0,   394,   903,    63,
#            4,     1,     2,   640,   903,     1,     3,     0, 25980,
#            1,     2,    14,     1,     3,   431,     0,   329,   221,
#           24,   903,     0,  1726,  4739,   241,    17,   117,     0,
#          378,  5231,     0,    33,    58,     7,    81,   329,  2040,
#            4,     1,     2,    14,     1,     2,    14, 31817, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818])

# %%
train_Y[0]
# Out:
# array([31816,   326,   391, 31817, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818, 31818,
#        31818, 31818, 31818, 31818, 31818])

# %%
BUFFER_SIZE = 20000
# BATCH_SIZE = 64
BATCH_SIZE = 256

# %%
# train_dataset = tf.data.Dataset.from_tensor_slices((train_X, train_Y)).shuffle(BUFFER_SIZE)
# train_dataset = train_dataset.batch(BATCH_SIZE, drop_remainder=True)
train_dataset = tf.data.Dataset.from_tensor_slices((train_X[:-10000], train_Y[:-10000])).shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE, drop_remainder=True)

val_dataset = tf.data.Dataset.from_tensor_slices((train_X[-10000:], train_Y[-10000:]))
val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
pt_batch, en_batch = next(iter(train_dataset))
pt_batch, en_batch
# Out:
# (<tf.Tensor: id=24, shape=(256, 200), dtype=int32, numpy=
#  array([[31816,  2878, 29623, ..., 31818, 31818, 31818],
#         [31816,   202,   429, ..., 31818, 31818, 31818],
#         [31816, 31819,   953, ..., 31818, 31818, 31818],
#         ...,
#         [31816,  1312,  3588, ...,   691,   116,     0],
#         [31816,   342,   192, ..., 31818, 31818, 31818],
#         [31816,     0,   439, ...,    89,   222,     0]])>,
#  <tf.Tensor: id=25, shape=(256, 41), dtype=int32, numpy=
#  array([[31816,    57,    76, ..., 31818, 31818, 31818],
#         [31816,    80,     8, ..., 31818, 31818, 31818],
#         [31816,    57,   980, ..., 31818, 31818, 31818],
#         ...,
#         [31816,   528,    43, ..., 26748,     0, 31817],
#         [31816,    15,   666, ..., 31818, 31818, 31818],
#         [31816,  3067,   597, ..., 31818, 31818, 31818]])>)

# %%
import tensorflow as tf

import time
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

    # 将 sin 应用于数组中的偶数索引（indices）；2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # 将 cos 应用于数组中的奇数索引；2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

    # 添加额外的维度来将填充加到
    # 注意力对数（logits）。
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
    """
    tf.linalg.band_part(
        input,
        num_lower,
        num_upper,
        name=None
    )
    input:输入的张量.
    num_lower:下三角矩阵保留的副对角线数量，从主对角线开始计算，相当于下三角的带宽。取值为负数时，则全部保留。
    num_upper:上三角矩阵保留的副对角线数量，从主对角线开始计算，相当于上三角的带宽。取值为负数时，则全部保留。
    """
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)

# %%
def scaled_dot_product_attention(q, k, v, mask):
    """计算注意力权重。
    q, k, v 必须具有匹配的前置维度。
    k, v 必须有匹配的倒数第二个维度，例如：seq_len_k = seq_len_v。
    虽然 mask 根据其类型（填充或前瞻）有不同的形状，
    但是 mask 必须能进行广播转换以便求和。

    参数:
    q: 请求的形状 == (..., seq_len_q, depth)
    k: 主键的形状 == (..., seq_len_k, depth)
    v: 数值的形状 == (..., seq_len_v, depth_v)
    mask: Float 张量，其形状能转换成
          (..., seq_len_q, seq_len_k)。默认为None。

    返回值:
    输出，注意力权重
    """

    matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

    # 缩放 matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    # 将 mask 加入到缩放的张量上。
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)  

    # softmax 在最后一个轴（seq_len_k）上归一化，因此分数
    # 相加等于1。
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

    return output, attention_weights

# %%
def print_out(q, k, v):
    temp_out, temp_attn = scaled_dot_product_attention(
        q, k, v, None)
    print ('Attention weights are:')
    print (temp_attn)
    print ('Output is:')
    print (temp_out)

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)
        
    def split_heads(self, x, batch_size):
        """
        分拆最后一个维度到 (num_heads, depth).
        转置结果使得形状为 (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    
    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)

        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

        concat_attention = tf.reshape(scaled_attention, 
                                      (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

        return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)
        # (x-mean) / std,
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):

        attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
    def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)
        
        # v, k, q, mask
        attn2, attn_weights_block2 = self.mha2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, 
                                                self.d_model)


        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)
        
    def call(self, x, training, mask):

        seq_len = tf.shape(x)[1]

        # 将嵌入和位置编码相加。
        x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
        
        # 为什么要乘以embedding size的开方？
        # 猜测是因为embedding matrix的初始化方式是xavier init，这种方式的方差是1/embedding size，
        # 因此乘以embedding size的开方使得embedding matrix的方差是1，在这个scale下可能更有利于embedding matrix的收敛。
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x  # (batch_size, input_seq_len, d_model)

# %%
# sample_encoder = Encoder(num_layers=2, d_model=512, num_heads=8, 
#                          dff=2048, input_vocab_size=8500,
#                          maximum_position_encoding=10000)

# sample_encoder_output = sample_encoder(tf.random.uniform((64, 62)), 
#                                        training=False, mask=None)

# print (sample_encoder_output.shape)  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                           for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)
    
    def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):

        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            # v, k, q
            x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                                 look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, 
               target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, 
                               input_vocab_size, pe_input, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                               target_vocab_size, pe_target, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
    def call(self, inp, tar, training, enc_padding_mask, 
           look_ahead_mask, dec_padding_mask):

        enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

        # dec_output.shape == (batch_size, tar_seq_len, d_model)
        dec_output, attention_weights = self.decoder(
            tar, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

        return final_output, attention_weights

# %%
num_layers = 4
# d_model = 128
d_model = 512
dff = 512
num_heads = 8
dropout_rate = 0.1
len(vocab)
input_vocab_size = len(vocab)
target_vocab_size = len(vocab)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size, 
                          pe_input=input_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
def create_masks(inp, tar):
    # 编码器填充遮挡
    enc_padding_mask = create_padding_mask(inp)

    # 在解码器的第二个注意力模块使用。
    # 该填充遮挡用于遮挡编码器的输出。
    dec_padding_mask = create_padding_mask(inp)

    # 在解码器的第一个注意力模块使用。
    # 用于填充（pad）和遮挡（mask）解码器获取到的输入的后续标记（future tokens）。
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "C:/Users/Administrator/Desktop/transformer_task-20200413T125800Z-001/transformer_task/checkpoints-20200415T073302Z-001/checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# 如果检查点存在，则恢复最新的检查点。
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
EPOCHS = 10

# %%
# 该 @tf.function 将追踪-编译 train_step 到 TF 图中，以便更快地
# 执行。该函数专用于参数张量的精确形状。为了避免由于可变序列长度或可变
# 批次大小（最后一批次较小）导致的再追踪，使用 input_signature 指定
# 更多的通用形状。

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
  
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)
  
    with tf.GradientTape() as tape:
        predictions, _ = transformer(inp, tar_inp, 
                                     True, 
                                     enc_padding_mask, 
                                     combined_mask, 
                                     dec_padding_mask)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tar_real, predictions)

# %%
for epoch in range(EPOCHS):
    start = time.time()
  
    train_loss.reset_states()
    train_accuracy.reset_states()
  
    # inp -> portuguese, tar -> english
    for (batch, (inp, tar)) in enumerate(train_dataset):
        train_step(inp, tar)

        if batch % 50 == 0:
            print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
                epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
    if (epoch + 1) % 2 == 0:
      inp1, tar1 = next(iter(val_dataset))
      train_step(inp1, tar1)
      print ('val_Loss {:.4f} val_Accuracy {:.4f}'.format(train_loss.result(), train_accuracy.result()))
      ckpt_save_path = ckpt_manager.save()
      print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                        ckpt_save_path))
    
    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 9.9615 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 9.3404 Accuracy 0.3111
# Epoch 1 Batch 100 Loss 8.5399 Accuracy 0.4496
# Epoch 1 Batch 150 Loss 7.9723 Accuracy 0.4954
# Epoch 1 Batch 200 Loss 7.4499 Accuracy 0.5152
# Epoch 1 Batch 250 Loss 6.9098 Accuracy 0.5276
# Epoch 1 Loss 6.5527 Accuracy 0.5330
# Time taken for 1 epoch: 390.83719420433044 secs
#
# Epoch 2 Batch 0 Loss 3.4268 Accuracy 0.5881
# Epoch 2 Batch 50 Loss 3.0447 Accuracy 0.5943
# Epoch 2 Batch 100 Loss 2.8348 Accuracy 0.5954
# Epoch 2 Batch 150 Loss 2.7189 Accuracy 0.6011
# Epoch 2 Batch 200 Loss 2.6584 Accuracy 0.6028
# Epoch 2 Batch 250 Loss 2.6051 Accuracy 0.6060
# val_Loss 2.5742 val_Accuracy 0.6076
# Saving checkpoint for epoch 2 at /content/drive/My Drive/transformer_task1/transformer_task/data/checkpoints/ckpt-1
# Epoch 2 Loss 2.5742 Accuracy 0.6076
# Time taken for 1 epoch: 430.3715443611145 secs
#
# Epoch 3 Batch 0 Loss 2.1403 Accuracy 0.6421
# Epoch 3 Batch 50 Loss 2.1307 Accuracy 0.6471
# Epoch 3 Batch 100 Loss 2.1149 Accuracy 0.6476
# Epoch 3 Batch 150 Loss 2.0821 Accuracy 0.6500
# Epoch 3 Batch 200 Loss 2.0725 Accuracy 0.6487
# Epoch 3 Batch 250 Loss 2.0585 Accuracy 0.6486
# Epoch 3 Loss 2.0504 Accuracy 0.6482
# Time taken for 1 epoch: 375.1958017349243 secs
#
# Epoch 4 Batch 0 Loss 1.7690 Accuracy 0.6751
# Epoch 4 Batch 50 Loss 1.7910 Accuracy 0.6743
# Epoch 4 Batch 100 Loss 1.7737 Accuracy 0.6750
# Epoch 4 Batch 150 Loss 1.7606 Accuracy 0.6748
# Epoch 4 Batch 200 Loss 1.7649 Accuracy 0.6725
# Epoch 4 Batch 250 Loss 1.7615 Accuracy 0.6716
# val_Loss 1.7565 val_Accuracy 0.6714
# Saving checkpoint for epoch 4 at /content/drive/My Drive/transformer_task1/transformer_task/data/checkpoints/ckpt-2
# Epoch 4 Loss 1.7565 Accuracy 0.6714
# Time taken for 1 epoch: 427.44323921203613 secs
#
# Epoch 5 Batch 0 Loss 1.5711 Accuracy 0.6939
# Epoch 5 Batch 50 Loss 1.5557 Accuracy 0.6964
# Epoch 5 Batch 100 Loss 1.5648 Accuracy 0.6935
# Epoch 5 Batch 150 Loss 1.5578 Accuracy 0.6927
# Epoch 5 Batch 200 Loss 1.5640 Accuracy 0.6903
# Epoch 5 Batch 250 Loss 1.5722 Accuracy 0.6880
# Epoch 5 Loss 1.5707 Accuracy 0.6876
# Time taken for 1 epoch: 375.424756526947 secs
#
# Epoch 6 Batch 0 Loss 1.5039 Accuracy 0.6884
# Epoch 6 Batch 50 Loss 1.4181 Accuracy 0.7089
# Epoch 6 Batch 100 Loss 1.4214 Accuracy 0.7064
# Epoch 6 Batch 150 Loss 1.4195 Accuracy 0.7056
# Epoch 6 Batch 200 Loss 1.4299 Accuracy 0.7026
# Epoch 6 Batch 250 Loss 1.4376 Accuracy 0.7006
# val_Loss 1.4398 val_Accuracy 0.6998
# Saving checkpoint for epoch 6 at /content/drive/My Drive/transformer_task1/transformer_task/data/checkpoints/ckpt-3
# Epoch 6 Loss 1.4398 Accuracy 0.6998
# Time taken for 1 epoch: 423.92828249931335 secs
#
# Epoch 7 Batch 0 Loss 1.3148 Accuracy 0.7159
# Epoch 7 Batch 50 Loss 1.3080 Accuracy 0.7193
# Epoch 7 Batch 100 Loss 1.3059 Accuracy 0.7182
# Epoch 7 Batch 150 Loss 1.3096 Accuracy 0.7166
# Epoch 7 Batch 200 Loss 1.3217 Accuracy 0.7134
# Epoch 7 Batch 250 Loss 1.3310 Accuracy 0.7112
# Epoch 7 Loss 1.3348 Accuracy 0.7102
# Time taken for 1 epoch: 375.2960522174835 secs
#
# Epoch 8 Batch 0 Loss 1.2397 Accuracy 0.7202
# Epoch 8 Batch 50 Loss 1.2217 Accuracy 0.7263
# Epoch 8 Batch 100 Loss 1.2161 Accuracy 0.7270
# Epoch 8 Batch 150 Loss 1.2180 Accuracy 0.7255
# Epoch 8 Batch 200 Loss 1.2273 Accuracy 0.7232
# Epoch 8 Batch 250 Loss 1.2397 Accuracy 0.7205
# val_Loss 1.2444 val_Accuracy 0.7196
# Saving checkpoint for epoch 8 at /content/drive/My Drive/transformer_task1/transformer_task/data/checkpoints/ckpt-4
# Epoch 8 Loss 1.2444 Accuracy 0.7196
# Time taken for 1 epoch: 422.11590695381165 secs
#
# Epoch 9 Batch 0 Loss 1.0492 Accuracy 0.7575
# Epoch 9 Batch 50 Loss 1.1259 Accuracy 0.7389
# Epoch 9 Batch 100 Loss 1.1290 Accuracy 0.7368
# Epoch 9 Batch 150 Loss 1.1289 Accuracy 0.7359
# Epoch 9 Batch 200 Loss 1.1448 Accuracy 0.7322
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-6d2409e55717> in <module>()
#       7     # inp -> portuguese, tar -> english
#       8     for (batch, (inp, tar)) in enumerate(train_dataset):
# ----> 9         train_step(inp, tar)
#      10
#      11         if batch % 50 == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
def self1(x):
    # inp_sentence = tokenizer_pt.encode(inp_sentence)
    encoder_input = tf.expand_dims(x.tolist() , 0)

    # 因为目标是英语，输入 transformer 的第一个词应该是
    # 英语的开始标记。
    decoder_input = [31816]
    output = tf.expand_dims(decoder_input, 0)
    for i in range(41):
        enc_padding_mask, combined_mask, dec_padding_mask = create_masks(
            encoder_input, output)

        # predictions.shape == (batch_size, seq_len, vocab_size)
        predictions, attention_weights = transformer(encoder_input, 
                                                     output,
                                                     False,
                                                     enc_padding_mask,
                                                     combined_mask,
                                                     dec_padding_mask)

        # 从 seq_len 维度选择最后一个词
        predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)

        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        # 如果 predicted_id 等于结束标记，就返回结果
        if predicted_id == 31817:
            return tf.squeeze(output, axis=0)#, attention_weights

        # 连接 predicted_id 与输出，作为解码器的输入传递到解码器。
        output = tf.concat([output, predicted_id], axis=-1)
    return tf.squeeze(output, axis=0)

# %%
def tes(x):
  result= self1(x)
  re=''
  sentence =[reverse_vocab[i] for i in result.numpy() if i < len(vocab)+4]
  for i in sentence[1:]:
    re+=i
  sentence=re
#   sentence=sentence.lstrip(' ，！。')
#   sentence=sentence.replace(' ','')
  if sentence=='':
      sentence='随时联系'
  return sentence

# %%
from tqdm import tqdm
a=[]
for i in tqdm(range(len(test_X))):
  a.append(tes(test_X[i]))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 20000/20000 [18:34:58<00:00,  3.34s/it]

# %%
a
# Out:
# ['这种情况需要更换机油。',
#  '这种情况需要检查下',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否是否问题。',
#  '这种情况建议检查下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要检查更换。',
#  '这种情况需要检查下下下。',
#  '这种情况需要检查下是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况需要检查下下',
#  '这种情况建议检查下下下下下',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况建议检查下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下下下更换。',
#  '这种情况建议检查更换',
#  '这种情况需要更换',
#  '这种情况建议检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况建议检查下下下下检查下',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下更换。',
#  '建议更换',
#  '这种情况建议检查下下下',
#  '这种情况需要更换。',
#  '这种情况建议检查下下更换。',
#  '这种情况需要更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查更换。',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况建议检查下下',
#  '这种情况需要检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议更换',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下。',
#  '这种情况建议检查下',
#  '这种情况需要检查更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况检查下是否是否是否是否问题。',
#  '这种情况需要检查下。',
#  '这种情况需要更换。',
#  '这种情况需要检查下下是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下',
#  '这种情况需要更换机油。',
#  '这种情况需要更换。',
#  '这种情况建议检查下下更换',
#  '这种情况需要更换机油。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '这种情况需要检查下下。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下下下更换。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下下检查下',
#  '这种情况需要检查下下下。',
#  '检查更换',
#  '这种情况需要检查下下下更换。',
#  '检查下',
#  '这种情况检查下是否是否是否是否是否是否是否是否是否是否问题。',
#  '检查下',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况需要检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况建议检查下下',
#  '这种情况需要检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下',
#  '这种情况需要更换更换更换更换。',
#  '建议检查下',
#  '这种情况建议检查下下下是否问题。',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换',
#  '这种情况建议检查下下',
#  '这种情况需要检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下更换',
#  '检查下',
#  '这种情况建议检查下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查更换',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '更换机油机油机油机油',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否问题',
#  '建议更换',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下',
#  '检查更换',
#  '建议更换',
#  '这种情况建议检查下下',
#  '这种情况检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要更换机油。',
#  '这种情况需要检查下下',
#  '这种情况建议检查下',
#  '这种情况建议检查下检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下问题',
#  '这种情况建议检查下下下检查下',
#  '这种情况需要更换',
#  '这种情况需要更换机油。',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否是否是否是否问题',
#  '更换更换机油机油',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下',
#  '检查更换',
#  '建议更换',
#  '这种情况需要更换',
#  '建议更换',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否问题。',
#  '这种情况建议检查下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否问题',
#  '建议更换',
#  '这种情况建议检查下',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下',
#  '这种情况建议检查更换',
#  '这种情况建议检查下下下',
#  '这种情况需要检查下。',
#  '这种情况建议检查下下下',
#  '这种情况需要检查下是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下。',
#  '检查更换',
#  '这种情况需要检查下',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下下检查下检查下',
#  '这种情况需要检查下下是否是否问题。',
#  '这种情况需要更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下下下更换。',
#  '这种情况建议检查下下',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '这种情况建议检查下下',
#  '检查下',
#  '更换更换更换更换更换更换。',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '这种情况需要检查下下发动机是否是否问题。',
#  '这种情况需要检查下下下是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况需要检查更换是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要检查下下下发动机是否问题。',
#  '这种情况需要更换。',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下下下',
#  '这种情况需要检查下是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况需要更换',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下',
#  '这种情况建议检查下',
#  '这种情况检查下是否是否是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况建议更换',
#  '这种情况需要更换。',
#  '检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换更换',
#  '这种情况需要更换',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下',
#  '这种情况需要更换。',
#  '这种情况建议检查下下下更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否是否是否问题。',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况建议检查下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况检查下是否是否是否是否是否是否问题。',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况建议检查检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下',
#  '这种情况需要检查下是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下检查下',
#  '这种情况需要检查下下是否是否是否是否问题。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下',
#  '这种情况需要检查更换是否是否是否是否是否问题。',
#  '这种情况需要检查下。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换更换机油。',
#  '这种情况建议检查下下是否是否问题',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下下下下问题',
#  '这种情况建议检查下下下下',
#  '这种情况建议检查下检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下是否是否是否问题。',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要更换更换。',
#  '这种情况建议检查下下',
#  '检查更换',
#  '这种情况建议检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下',
#  '检查下',
#  '检查下',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要更换机油',
#  '这种情况建议检查下下下下。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查更换是否是否是否问题',
#  '这种情况建议检查下下下下检查下',
#  '这种情况需要检查下是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要检查更换是否是否是否是否是否是否问题。',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下检查下下检查下',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '这种情况需要检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '这种情况需要检查下下是否是否是否问题。',
#  '这种情况需要检查下下下发动机是否问题。',
#  '这种情况需要检查下下下是否问题。',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要更换',
#  '这种情况建议检查下下下',
#  '检查下',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况建议检查下下下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下更换。',
#  '这种情况建议检查下下下下问题',
#  '这种情况需要检查下下发动机是否是否是否是否是否是否问题。',
#  '这种情况需要检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下下更换。',
#  '这种情况建议检查下下',
#  '这种情况需要检查下下检查下是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '这种情况需要检查更换是否是否是否是否问题。',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况建议检查下下',
#  '这种情况需要检查更换是否是否是否是否是否问题。',
#  '这种情况建议检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议更换',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下',
#  '这种情况需要检查下下下是否问题。',
#  '检查下',
#  '这种情况需要检查下。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下下问题',
#  '这种情况需要更换。',
#  '更换机油',
#  '这种情况需要更换更换更换。',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下检查下',
#  '这种情况需要检查下下。',
#  '这种情况建议检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下下下问题',
#  '这种情况建议检查下',
#  '这种情况需要检查下',
#  '这种情况需要检查下。',
#  '这种情况需要更换',
#  '这种情况需要检查下下更换',
#  '这种情况建议检查下',
#  '这种情况需要检查下',
#  '这种情况建议检查下',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况建议检查下下下检查下是否是否是否是否是否是否问题',
#  '检查下',
#  '建议更换',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要检查下发动机是否是否是否是否是否是否是否是否是否问题。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下下发动机是否问题。',
#  '这种情况建议检查下下下下检查下检查下是否是否是否问题',
#  '这种情况需要更换更换更换更换',
#  '这种情况建议检查下下下下检查下检查下下是否是否是否问题',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题<PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况需要检查下是否是否是否是否是否问题。',
#  '这种情况建议检查下下检查下是否是否是否是否是否问题。',
#  '这种情况建议检查下下下下更换。',
#  '这种情况需要更换机油。',
#  '这种情况建议检查下下下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否。',
#  '检查下',
#  '这种情况需要检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下',
#  '这种情况需要检查下是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查下下下下检查下检查下下下是否下是否下是否问题',
#  '这种情况需要更换更换机油。',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况需要更换机油。',
#  '这种情况需要更换',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换更换',
#  '检查下',
#  '这种情况建议检查下',
#  '这种情况需要更换机油。',
#  '这种情况建议更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况需要检查下',
#  '这种情况需要更换更换。',
#  '这种情况建议检查下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否问题',
#  '这种情况建议检查下下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下下是否是否是否是否问题。',
#  '这种情况需要检查下下下',
#  '这种情况检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否是否问题。',
#  '检查下',
#  '这种情况建议检查下下下下问题。',
#  '检查更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下',
#  '这种情况建议检查下检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题<PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否问题。',
#  '这种情况建议检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下下是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况需要检查更换。',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否是否问题。',
#  '这种情况需要检查下',
#  '这种情况需要检查下。',
#  '这种情况需要检查更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否问题',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况建议检查下下下',
#  '这种情况需要检查下下是否问题。',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '检查更换',
#  '这种情况建议检查下下下下问题',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换机油。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况需要更换',
#  '这种情况需要更换更换',
#  '这种情况需要更换。',
#  '这种情况需要更换',
#  '这种情况需要更换',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下下检查下',
#  '这种情况建议检查下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否',
#  '这种情况需要检查下是否是否问题',
#  '这种情况建议检查下下下下',
#  '检查下是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '检查下',
#  '这种情况建议检查更换',
#  '这种情况建议检查下下',
#  '这种情况需要更换',
#  '这种情况需要更换机油。',
#  '这种情况需要更换。',
#  '这种情况需要检查下。',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况建议检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要检查下',
#  '这种情况检查下是否是否是否是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否问题。',
#  '这种情况需要检查更换是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换',
#  '这种情况建议更换。',
#  '这种情况建议更换',
#  '这种情况需要检查下。',
#  '这种情况需要检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况需要检查下',
#  '检查下',
#  '这种情况建议检查下检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查更换是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '更换机油',
#  '这种情况需要检查下',
#  '这种情况需要检查下是否是否是否是否问题',
#  '更换更换更换更换更换更换更换',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换机油。',
#  '这种情况需要检查下。',
#  '这种情况需要检查下下是否问题。',
#  '这种情况需要更换机油机油。',
#  '建议更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下发动机是否是否是否是否是否是否是否问题。',
#  '这种情况建议检查检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '更换更换更换机油',
#  '这种情况建议检查检查下是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况建议检查下下下是否问题',
#  '这种情况需要更换',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下',
#  '检查下',
#  '这种情况建议检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下下检查下',
#  '这种情况需要检查下是否问题。',
#  '检查下',
#  '检查更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换更换。',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要更换更换更换。',
#  '这种情况建议检查下下是否是否问题。',
#  '这种情况建议检查下下下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下',
#  '这种情况需要更换',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '更换更换更换更换更换更换更换',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况需要检查下是否是否是否问题',
#  '这种情况需要检查下。',
#  '这种情况建议检查下',
#  '这种情况需要检查下。',
#  '这种情况建议检查下下检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查更换。',
#  '检查下',
#  '这种情况需要更换更换。',
#  '这种情况需要检查下。',
#  '这种情况需要检查下是否是否是否是否问题',
#  '这种情况需要检查下下。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况建议检查下下更换。',
#  '检查下',
#  '这种情况建议检查下下',
#  '这种情况建议检查下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下',
#  '这种情况需要检查下是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下',
#  '这种情况建议检查检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否更换',
#  '这种情况需要检查下下更换。',
#  '检查下是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下检查下',
#  '这种情况需要检查下下是否是否是否问题。',
#  '检查下',
#  '这种情况需要更换机油。',
#  '这种情况需要更换',
#  '建议检查下',
#  '这种情况需要更换机油。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '更换更换机油。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查更换',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '建议更换',
#  '这种情况需要检查下下更换。',
#  '这种情况建议检查下下下下',
#  '这种情况需要更换。',
#  '这种情况需要检查下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换更换。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '检查更换是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换机油。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '检查更换',
#  '这种情况需要检查下下是否是否问题。',
#  '这种情况建议检查下下下检查下检查下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下下',
#  '这种情况建议检查下下下。',
#  '这种情况需要更换。',
#  '检查下',
#  '这种情况建议检查检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换机油。',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下是否是否问题。',
#  '更换更换更换',
#  '检查更换',
#  '这种情况需要检查下下更换',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '这种情况需要检查下。',
#  '这种情况需要检查下下下更换。',
#  '这种情况需要检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况需要检查下是否是否问题',
#  '这种情况建议检查下下',
#  '检查下',
#  '这种情况需要更换',
#  '这种情况建议检查下',
#  '这种情况需要检查下下下问题。',
#  '这种情况需要更换更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况建议更换。',
#  '这种情况建议检查下下检查下',
#  '这种情况需要更换',
#  '这种情况需要更换。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下。',
#  '这种情况需要更换',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下是否问题',
#  '这种情况建议检查下',
#  '这种情况需要检查下。',
#  '这种情况需要检查下下',
#  '这种情况需要更换。',
#  '检查下',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下下检查下下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议更换',
#  '这种情况需要检查下下是否是否问题。',
#  '这种情况需要更换机油。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下下问题',
#  '这种情况需要检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况建议检查检查下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况建议检查下下',
#  '建议更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下问题',
#  '这种情况需要更换机油。',
#  '检查下',
#  '检查下',
#  '这种情况建议检查更换。',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否是否是否是否是否问题。',
#  '检查更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '检查更换',
#  '检查下',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下下。',
#  '这种情况建议检查下下下下',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下',
#  '这种情况建议检查下下',
#  '检查下',
#  '建议检查下',
#  '这种情况建议检查下',
#  '这种情况需要更换',
#  '这种情况需要检查下。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查更换',
#  '这种情况建议检查下检查下下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况需要更换。',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '这种情况建议检查下下',
#  '检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下下下检查下下',
#  '这种情况需要更换。',
#  '检查下',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下',
#  '这种情况需要检查下是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换更换更换。',
#  '这种情况需要检查下下。',
#  '这种情况需要更换机油。',
#  '这种情况需要检查下。',
#  '更换机油机油机油机油机油机油机油机油机油机油',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下检查下',
#  '检查下',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况建议检查下',
#  '这种情况建议更换',
#  '这种情况需要检查下下下更换。',
#  '这种情况建议检查下检查下下',
#  '检查更换',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下',
#  '这种情况需要更换。',
#  '这种情况建议检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下下问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换更换。',
#  '这种情况建议检查下下检查下',
#  '更换更换更换更换',
#  '这种情况需要检查下下下问题。',
#  '这种情况需要更换机油。',
#  '这种情况需要检查下是否是否是否问题。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换机油。',
#  '这种情况建议更换',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '检查下',
#  '检查下',
#  '这种情况建议检查下下',
#  '这种情况建议检查下下下下检查下',
#  '这种情况建议检查下检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要更换。',
#  '这种情况需要检查下下下更换。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下问题',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换更换',
#  '这种情况建议检查下下下下检查下检查下下',
#  '这种情况需要检查下',
#  '检查下',
#  '这种情况建议检查下下检查下是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下下。',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换',
#  '这种情况建议检查检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下',
#  '更换机油',
#  '检查下',
#  '检查更换',
#  '这种情况需要检查下是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下下是否问题。',
#  '这种情况建议检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '建议更换',
#  '这种情况需要检查下下下问题。',
#  '这种情况需要检查下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况建议检查下下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况需要检查下下是否是否问题。',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否是否是否问题。',
#  '这种情况需要更换',
#  '这种情况需要检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况建议更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下下',
#  '这种情况建议检查下下检查下下检查下',
#  '这种情况需要检查下是否是否是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下问题',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查更换。',
#  '这种情况需要更换',
#  '这种情况建议检查下下下检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换。',
#  '检查更换',
#  '检查下',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '这种情况需要检查下下是否问题。',
#  '这种情况建议检查下',
#  '这种情况建议检查下下下下问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况建议检查下下',
#  '这种情况需要更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下下下下问题。',
#  '这种情况建议检查下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况建议检查下',
#  '检查下<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要检查下',
#  '这种情况需要检查下是否是否是否是否问题。',
#  '这种情况需要检查下下检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下是否是否是否问题。',
#  '这种情况建议检查下',
#  '这种情况需要更换。',
#  '检查下',
#  '检查下',
#  '这种情况需要更换。',
#  '这种情况需要检查下是否是否是否是否是否是否是否是否问题。',
#  '检查下',
#  '检查下',
#  '这种情况建议检查下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '这种情况需要更换',
#  '这种情况需要检查下',
#  '检查下',
#  '检查下',
#  '这种情况建议检查下',
#  '检查下',
#  '这种情况建议检查下下是否是否问题',
#  '这种情况建议检查下',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '这种情况需要检查下下下',
#  '检查<PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD><PAD>',
#  '检查下是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要检查下',
#  '检查更换',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换。',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况建议检查下下下下',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '检查下',
#  '这种情况建议检查下',
#  '这种情况需要更换更换。',
#  '这种情况需要检查下是否是否问题。',
#  '检查下',
#  '这种情况需要检查下下',
#  '这种情况需要检查更换是否是否是否是否是否问题',
#  '检查下是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否是否问题',
#  '这种情况需要更换',
#  ...]
